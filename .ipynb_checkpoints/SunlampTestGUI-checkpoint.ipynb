# %%
import numpy as np
import PySimpleGUI as sg
import random as random

# %%
hex(255)[2:]
# Out:
# 'ff'

# %%
random.sample(range(1, 17), 16)
# Out:
# [12, 3, 13, 11, 2, 16, 1, 4, 15, 5, 7, 6, 8, 9, 10, 14]

# %%
testDat = np.genfromtxt("test_rgb_array", delimiter = ',')
print(testDat[0, :])
# Out:
# (255.0, 232.0, 165.0)

# %%
print(np.shape(testDat))
# Out:
# (8, 3)

# %%
testDat = np.genfromtxt("test_rgb_array", delimiter = ',')

PORT_NAME = '/dev/ttyUSB0'  # Linux (might be /dev/ttyACM0, /dev/ttyUSB1, etc.)
# PORT_NAME = 'COM3'        # Windows (Change to the COM port your Arduino is connected to)

# Open the serial port
#ser = serial.Serial(PORT_NAME, 9600, timeout=1)
#ser.flush()

# Define the window layout
layout = [[sg.Button('Test RGB demo sequence')],
          [sg.Exit()]]

# Create the window
window = sg.Window('SUNLAMP', layout)

while True:
    event, values = window.read()

    if event == sg.WINDOW_CLOSED or event == 'Exit':
        break
    if event == 'Test RGB demo sequence':
        
        steps = 10
        i=0

        def get_color_step(color1, color2, t):

            r = int(color1[0] + (color2[0] - color1[0]) * t)
            g = int(color1[1] + (color2[1] - color1[1]) * t)
            b = int(color1[2] + (color2[2] - color1[2]) * t)

            return (r, g, b)

        while i < np.shape(testDat)[0]-1:
            print(i)
            if i == 0:
                window['-BACKGROUND-'].update(background_color='yellow')  # Change to desired color 
                #for k in random.sample(range(1, 17), 16):
                    #print(int(testDat[i, 0]), int(testDat[i, 1]), int(testDat[i, 1]), 255, k)
                i += 1
            else:
                start = testDat[i, :]
                end = testDat[i+1, :]

                for j in range(steps+1):
                    t = j/steps
                    interColor = get_color_step(start, end, t)
                    #for k in random.sample(range(1,17), 16):
                        #print(int(interColor[0]), int(interColor[1]), int(interColor[2]), 255, k)
                i += 1



window.close()
#ser.close()  # Close the serial connection
# Out:
# 0
# ** Error looking up your element using the key:  -BACKGROUND- The closest matching key:  None
# ** Your update is being ignored because you supplied a bad key earlier **
# 1
# 2
# 3
# 4
# 5
# 6

# %%
steps = 10
i=0

fig, ax = plt.subplots(figsize=(5, 8*steps))

def get_color_step(color1, color2, t):
    
    r = int(color1[0] + (color2[0] - color1[0]) * t)
    g = int(color1[1] + (color2[1] - color1[1]) * t)
    b = int(color1[2] + (color2[2] - color1[2]) * t)

    return (r, g, b)
        
while i < np.shape(testDat)[0]-1:
    print(i)
    if i == 0:
        rect = patches.Rectangle((0, i), 1, 1, linewidth=0, edgecolor='none', 
                                     facecolor=(int(testDat[i, 0])/255, int(testDat[i, 1])/255, 
                                                int(testDat[i, 2])/255))
        ax.add_patch(rect)
        #for k in random.sample(range(1, 17), 16):
            #print(int(testDat[i, 0]), int(testDat[i, 1]), int(testDat[i, 1]), 255, k)
        i += 1
    else:
        start = testDat[i, :]
        end = testDat[i+1, :]
        
        for j in range(steps+1):
            t = j/steps
            interColor = get_color_step(start, end, t)
            rect = patches.Rectangle((0, i), 1, 1, linewidth=0, edgecolor='none', 
                     facecolor=(int(interColor[0])/255, int(interColor[1])/255, 
                                int(interColor[2])/255))
            ax.add_patch(rect)
            #for k in random.sample(range(1,17), 16):
                #print(int(interColor[0]), int(interColor[1]), int(interColor[2]), 255, k)
        i += 1

                
plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def get_color_step(color1, color2, t):
    
    r = int(start_color[0] + (end_color[0] - start_color[0]) * t)
    g = int(start_color[1] + (end_color[1] - start_color[1]) * t)
    b = int(start_color[2] + (end_color[2] - start_color[2]) * t)

    return (r, g, b)


start = [255, 232, 165] 
end = [255, 143, 128]     

steps = 50  # How many steps you want in the transition
colors = []

for i in range(steps + 1):
    t = i / steps
    color = interpolate_color(start, end, t)
    colors.append(color)

fig, ax = plt.subplots(figsize=(5, len(colors)))

for i, color in enumerate(colors):
    rect = patches.Rectangle((0, i), 1, 1, linewidth=0, edgecolor='none', facecolor=(color[0]/255, color[1]/255, color[2]/255))
    ax.add_patch(rect)

ax.set_xlim(0, 1)
ax.set_ylim(0, len(colors))
ax.axis("off")

plt.show()
